# %% [markdown]
# ### Was accidentally adding extra index columns.  Wanted to clean my CSV's so that I could still call them in the code without adding unnecessary code to the main project.

# %%
import pandas as pd

# %% [markdown]
# ### Clean latest BTC CSV, btc_articles_df_2021-09-26.csv:

# %%
btc_df = pd.read_csv('btc_articles_df_2021-09-26.csv', index_col=False)
btc_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                            Headlines             Date_Time  \
# 0  Hitting the Books: How Bitcoin is somehow wort...  2021-09-25T15:30:24Z
# 1  26,000 and Counting: America is Installing Hun...  2021-09-26T03:34:00Z
# 2  VoIP.ms Battles Week-Long Sustained DDoS-for-R...  2021-09-26T01:34:00Z
# 3  Cryptocurrency exchange Huobi to clean up exis...  2021-09-26T09:23:00Z
# 4  110,000 Affected by Epik Breach - Including Th...  2021-09-25T22:34:00Z
#
#                                                  URL  \
# 0  https://www.engadget.com/hitting-the-books-the...
# 1  https://news.slashdot.org/story/21/09/26/02520...
# 2  https://tech.slashdot.org/story/21/09/26/00142...
# 3  https://www.reuters.com/world/china/cryptocurr...
# 4  https://yro.slashdot.org/story/21/09/25/153423...
#
# ...

# %%
btc_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Headlines', 'Date_Time', 'URL',
#        'Description', 'Content', 'Compound Sentiment', 'Positive Sentiment',
#        'Neutral Sentiment', 'Negative Sentiment'],
#       dtype='object')

# %%
btc_df.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'], inplace = True)
btc_df.head(3)
# Out:
#                                            Headlines             Date_Time  \
# 0  Hitting the Books: How Bitcoin is somehow wort...  2021-09-25T15:30:24Z
# 1  26,000 and Counting: America is Installing Hun...  2021-09-26T03:34:00Z
# 2  VoIP.ms Battles Week-Long Sustained DDoS-for-R...  2021-09-26T01:34:00Z
#
#                                                  URL  \
# 0  https://www.engadget.com/hitting-the-books-the...
# 1  https://news.slashdot.org/story/21/09/26/02520...
# 2  https://tech.slashdot.org/story/21/09/26/00142...
#
#                                          Description  \
# 0  Bitcoin and similar blockchain-based cryptos e...
# 1  The cryptocurrency-ATM company Coinmover has o...
# 2  Slashdot reader Striek writes: VoIP.ms, a Cana...
#
#                                              Content  Compound Sentiment  \
# 0  Bitcoin and similar blockchain-based cryptos e...              0.3400
# 1  The cryptocurrency-ATM company Coinmover has o...              0.0000
# ...

# %%
btc_df.to_csv('btc_articles_df_2021-09-26.csv', index=False)

# %% [markdown]
# ### Clean latest ETH CSV, eth_articles_df_2021-09-26.csv:

# %%
eth_df = pd.read_csv('eth_articles_df_2021-09-26.csv', index_col=False)
eth_df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
#
#                                            Headlines             Date_Time  \
# 0  JPMorgan Warns Big Investors Are Suddenly Dump...  2021-09-26T10:15:44Z
# 1  Amid China's crackdown on crypto, here's how t...  2021-09-26T05:45:20Z
#
#                                                  URL  \
# 0  https://www.forbes.com/sites/billybambrough/20...
# 1  https://economictimes.indiatimes.com/markets/c...
#
#                                          Description  \
# 0  Ahead of China's latest bitcoin and crypto cra...
# 1  This month we had some good news too for BTC, ...
#
#                                              Content  Compound Sentiment  \
# 0  Bitcoin and cryptocurrency prices have fallen ...             -0.2732
# 1  Bitcoin, the largest cryptocurrency, started i...              0.8591
#
#    Positive Sentiment  Neutral Sentiment  Negative Sentiment
# ...

# %%
eth_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Headlines', 'Date_Time', 'URL',
#        'Description', 'Content', 'Compound Sentiment', 'Positive Sentiment',
#        'Neutral Sentiment', 'Negative Sentiment'],
#       dtype='object')

# %%
eth_df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
eth_df.head(2)
# Out:
#                                            Headlines             Date_Time  \
# 0  JPMorgan Warns Big Investors Are Suddenly Dump...  2021-09-26T10:15:44Z
# 1  Amid China's crackdown on crypto, here's how t...  2021-09-26T05:45:20Z
#
#                                                  URL  \
# 0  https://www.forbes.com/sites/billybambrough/20...
# 1  https://economictimes.indiatimes.com/markets/c...
#
#                                          Description  \
# 0  Ahead of China's latest bitcoin and crypto cra...
# 1  This month we had some good news too for BTC, ...
#
#                                              Content  Compound Sentiment  \
# 0  Bitcoin and cryptocurrency prices have fallen ...             -0.2732
# 1  Bitcoin, the largest cryptocurrency, started i...              0.8591
#
#    Positive Sentiment  Neutral Sentiment  Negative Sentiment
# 0               0.000              0.928               0.072
# 1               0.208              0.792               0.000

# %%
eth_df.to_csv('eth_articles_df_2021-09-26.csv', index=False)
